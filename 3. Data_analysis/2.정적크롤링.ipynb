","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5NDFi236bqczwxb2IivhJMoTfU0Sli6Td7LqbFU4iQyS2Hyf51kU7%2FHJL1qM2Pf%2Fak82fMG5Q7uLdr9HzzWaFRWi74nTI%2Bk0OjIBWexIpibH0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvbdMAtSn%2B9Id4vH4MuGzFJiErLLp1Ox71Vg1K%2FFXnNMQA\u0026ac=8910654\u0026src=6911604\u0026evtcd=BID_WIN\u0026x_ti=1500\u0026rk=j9_zBYpDeLujibfGSrt0zg\u0026eltts=M7VOe9IHGuzGTZd%2BRDXQiw%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","adomain":["www.samsung.com"],"cid":"1478801","crid":"2593300","exp":2096,"adm":"%3Cscript%20type%3D%22text%2Fjavascript%22%20src%3D%22https%3A%2F%2Fssl.ps ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="min-width:1340px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="link_search_special" id="special-input-logo-ex" style="display:none"></div> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.nclk_v2(this,"sch.action")' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"> <div class="ly_atcmp" data-atcmp-element=""> <div class="api_atcmp_wrap"> <div class="atcmp_fixer _recent_layer" style="display:none"> <div class="atcmp_header _recent_header"> <strong class="tit">최근 검색어</strong> <div class="option"> <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a> </div> </div> <div class="atcmp_container"> <ul class="kwd_lst _recent"></ul> <div class="kwd_info kwd_off _offMsg" style="display:none">검색어 저장 기능이 꺼져 있습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> <div class="kwd_info kwd_none _recentNone" style="display:none">최근 검색어 내역이 없습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">도움말</a>을 확인해주세요.</span></div> </div> <div class="atcmp_footer"> <span class="side_opt_area"> <span class="opt_item"> <a class="close _keywordO ...
#         window['EAGER-DATA']['GV'] = {
#             svt: '20240118162502',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(()=>{var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var s=i&&i.content&&i.content.input&&i.content.input.placeholder;if(s){var o=document.getElementById("query");o&&s&&o.setAttribute("title",s),o&&s&&o.setAttribute("placeholder",s)}}()</script> </body> </html>

# %% [markdown]
# ## 파서
#
# - 내가 원하는 데이터를 특정 패턴이나 순서로 추출하여 정보를 가공해주는 프로그램
#     - lxml
#         - c언어로 구현되어 속도가 가장 빠름
#
#     - html.parser
#         - lxml과 html5lib의 중간 속도
#
#     - html5lib
#         - 웹브라우저 형태로 HTML을 분석
#         - 속도가 가장 느림
#         - 가장 안정적

# %%
# html을 예쁘게 출력
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="fzoom" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="Referrer"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1190" name="viewport"/>
#   <title>
#    NAVER
#   </title>
#   <meta content="NAVER" name="apple-mobile-web-app-title"/>
#   <meta content="index,nofollow" name="robots"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/>
#   <meta content="네이버" property="og:title"/>
#   <meta content="https://www.naver.com/" property="og:url"/>
#   <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="" name="twitter:title"/>
#   <meta content="https://www.naver.com/" name="twitter:url"/>
#   <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"/>
#   <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/>
#   <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231130.css" rel="stylesheet"/>
#   <script>
#    window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"
#   </script>
#   <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js">
#   </script>
#   <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
#   </script>
#   <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js">
#   </script>
#   <script>
#    window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","excludeInPaging":false,"positionForPaging":0,"realtime":false,"filterList":[{"id":"ALL","name":"전체","defaultType":true},{"id":"BEST","name":"인기","defaultType":true},{"id":"ANIMAL","name":"동물","defaultType":false},{"id":"TRAVEL","name":"여행","defaultType":false},{"id":"WEDDING","name":"연애결혼","defaultType":false},{"id":"MOVIE","name":"영화","defaultType":false},{"id":"MOMKIDS","name":"육아","defaultType":false}],"needCologger":false,"ad":false,"@type":"PC-FEED-BLOCK","@code":"PC-FEED-RECOMMEND-FILTER-TAB","@template":"PC-FEED-RECOMMEND-FILTER-TAB"},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"제네시스 GV90 코치도어와 원 오브 원 비스포크 방식의 초호화 SUV","url":"https://in.naver.com/prayforwish/contents/internal/651292603991680","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fdiscovercrop-phinf.pstatic.net%2F%2FMjAyNDAxMTVfMTkg%2FMDAxNzA1MzE4NDU3NjU2.HHzdbKy7ahzSbxFhn-VdxRMeriMkFSsX03eB3Y-zXs4g.b3Chwiia44l9VuOSk7APuU4IV2K8uqQ2-B7P3MwFlVcg.JPEG%2Fimage_750x420.jpg%22&type=nf365_240&service=navermain"},"source":{"url":"https://blog.naver.com/prayforwish","name":"흙맥","service":"BLOG","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyMTA3MjlfNTcg%2FMDAxNjI3NTMxODU2OTYz.uO_feMIB4dkhuMZQ7MMiQSgYzZrL-0Fczl5JsUHh3CIg.wr6hkfZUmWxdAWg1YpQmKjSUV4sgNFUVAYscFp1czkIg.PNG.prayforwish%2FprofileImage.png%22&type=nf96_96&service=navermain"}},"labels":[{"type":"category","text":""}],"_id":"6441ca92c499cc07f334c46b"},{"@type":"MATERIAL-PC-FEED","title":"4년간 적금에 20만원 넣어 1000만원 목돈이 되었습니다","url":"https://in.naver.com/bloom/contents/internal/651122502510560","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fdiscovercrop-phinf.pstatic.net%2F%2FMjAyNDAxMTVfMTg1%2FMDAxNzA1MjcxNzM0MTM0.b7BTiCX8NTHRR5ElZijkW-mClBUmQxjCv5Mi9btJXh0g.O6-oa145K0V-uuicW76oxJt86XOWT1NRaHYG8vBU3Ykg.JPEG%2Fimage_374x246.jpg%22&type=nf365_240&service=navermain"},"source":{"url":"https://blog.naver.com/ishiseido77","name":"블룸앤아이유","service":"BLOG","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAxNzA2MjRfMjcz%2FMDAxNDk4Mjc3OTI0NjI2.LFtmMsYMpRj1rjyXCGZ-alsMrqWBHTg5IZawW4LyYHMg.czIxhLQ0OZTuR7pqX6lAQeOE2IriRFelHIEOulVrPqcg.JPEG.ishiseido77%2FprofileImage.jpg%22&type=nf96_96&service=navermain"}},"labels":[{"type":"category","text":""}],"_id":"6441ca92c499cc07f334c46c"},{"@type":"MATERIAL-PC-FEED","title":"나솔사계 짝 남자 1호 4호에게 몰리는 옥순즈(ft. 나는솔로 그후 직업)","url":"https://in.naver.com/treewg/contents/internal/650146117159168","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fdiscovercrop-phinf.pstatic.net%2F%2FMjAyNDAxMTJfODQg%2FMDAxNzA1MDM5NjA4OTA0.qUInbPm3nJhxnl_SjhIVyYP_-iau4IvmzCCPxykTPr8g.MEwdtqmiLHDLgoMd5XHmwvKbIrWBuA8TjKnx9gYW-_Qg.JPEG%2Fimage_374x246.jpg%22&type=nf365_240&service=navermain"},"source":{"url":"https://blog.naver.com
KCNC6WZCxEfYCTzahwf8SlITlG7-gg60HfGc1vNNh4LhnePcXJnMeT50KxdgVhni6716gureXUOTVRZBbrl9kP_ABqjao76jA6qc9VGj4XT4sem6capIu79i19gAVppfgjmlzDCKY6XqX3x0jbharqh_QWPttY2FVl-BCgqfozXmKFCETPhwtT2L6MEdocIfMygs7pUUiqP_4-upWSZEefW1Z6brh1IKm-s9Se28zUlTdINinaigRpGWOBtgWuRBh-FgfMUj7cxlVN5bWxIAweG0aGE_MORKu9w8qP05Hc4up9egpWbjZ_PlTrwJ2TBc0cBDeFpmhd5WWKO0S5N7fRd1eF-wSJ0wP6nDe3DiunsWfwA4C6VZ9J2EVdu0DTrbfGZejf0hioPH6wYSX4KwRz51dT6uBf7fkkn5IosxVc14mGDYncEXKlOihz7enhOBe3hH4uQcHvg==","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5NDFi236bqczwxb2IivhJMoTfU0Sli6Td7LqbFU4iQyS2Hyf51kU7%2FHJL1qM2Pf%2Fak82fMG5Q7uLdr9HzzWaFRWi74nTI%2Bk0OjIBWexIpibH0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvbdMAtSn%2B9Id4vH4MuGzFJiErLLp1Ox71Vg1K%2FFXnNMQA\u0026ac=8910654\u0026src=6911604\u0026evtcd=BID_WIN\u0026x_ti=1500\u0026rk=j9_zBYpDeLujibfGSrt0zg\u0026eltts=M7VOe9IHGuzGTZd%2BRDXQiw%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","adomain":["www.samsung.com"],"cid":"1478801","crid":"2593300","exp":2096,"adm":"%3Cscript%20type%3D%22text%2Fjavascript%22%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fassets%2Fjs%2Fpc%2Fmain%2Fmin%2Fpc.veta.core.min.js%22%3E%3C%2Fscript%3E%0D%0A%3Cscript%20type%3D%22text%2Fjavascript%22%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fglad%2Fbridge%2Fgfp-bridge.js%22%3E%3C%2Fscript%3E%0D%0A%3Cscript%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fassets%2Fjs%2Fpc%2Fmain%2Fmin%2Ftimeboard_premium_v202212.min.js%3F20230525%22%3E%3C%2Fscript%3E%0D%0A%3Clink%20href%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fassets%2Fcss%2Fpc%2Fmain%2Fmin%2Ftimeboard_premium_v202212.min.css%3F20230524%22%20rel%3D%22stylesheet%22%3E%0D%0A%3Cstyle%3E%0D%0A%09%40media%20%28max-width%3A%201000px%29%20%7B%0D%0A%09%09%2F%2A%20%EC%82%AC%EC%9D%B4%EC%A6%88%20%EC%A1%B0%EC%A0%95%EC%9D%80%20976px%20%EB%98%90%EB%8A%94%201480px%20%EC%9D%B4%EC%83%81%EC%9D%B8%20%EA%B2%BD%EC%9A%B0%EB%A7%8C%20%EC%A1%B4%EC%9E%AC.%20%EA%B7%B8%EB%9E%98%EC%84%9C%20%EA%B7%B8%20%EC%82%AC%EC%9D%B4%EA%B0%92%201000px%EB%A1%9C%20%EC%A7%80%EC%A0%95.%20%EC%B0%B8%EA%B3%A0%3A%20976px%EC%9C%BC%EB%A1%9C%20%EC%A7%80%EC%A0%95%ED%95%98%EB%A9%B4%20%EC%97%A3%EC%A7%80%EC%97%90%EC%84%9C%20%EC%9D%B8%E ...
#   </script>
#   <div id="wrap">
#    <div id="header" role="banner">
#     <div class="header_inner" id="topSearchWrap">
#      <div class="search_special_bg" id="special-logo">
#      </div>
#      <div class="ad_area" id="timeboard-ex" style="min-width:1340px">
#      </div>
#      <div class="search_area" id="search_area" style="border-color:#fff">
#       <div class="link_search_special" id="special-input-logo-ex" style="display:none">
#       </div>
#       <div class="search_group">
#        <div class="search_group_inner" id="search">
#         <h1 class="search_logo" id="special-input-logo">
#         </h1>
#         <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search">
#          <fieldset>
#           <legend class="blind">
#            검색
#           </legend>
#           <input name="where" type="hidden" value="nexearch"/>
#           <input id="sm" name="sm" type="hidden" value="top_hty"/>
#           <input id="fbm" name="fbm" type="hidden" value="0"/>
#           <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/>
#           <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/>
#           <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
#           <input id="ie" name="ie" type="hidden" value="utf8"/>
#           <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
#           <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
#           <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
#           <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
#           <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
#           <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
#           <div class="search_input_box">
#            <input autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." type="search"/>
#           </div>
#           <button class="btn_search" onclick='window.nclk_v2(this,"sch.action")' type="submit">
#            <span class="ico_btn_search_svg">
#             <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#              <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z">
#              </path>
#             </svg>
#            </span>
#            <span class="blind">
#             검색
#            </span>
#           </button>
#          </fieldset>
#         </form>
#         <div class="search_box">
#          <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button">
#           <span class="keybord_text">
#            <span class="blind">
#             입력도구
#            </span>
#           </span>
#          </button>
#          <div id="_nx_kbd" style="display:none">
#          </div>
#          <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button">
#           <span class="blind">
#            자동완성/최근검색어펼치기
#           </span>
#          </button>
#         </div>
#         <div class="layer_atcmp" id="autoFrame" style="display:none">
#          <div class="ly_atcmp" data-atcmp-element="">
#           <div class="api_atcmp_wrap">
#            <div class="atcmp_fixer _recent_layer" style="display:none">
#             <div class="atcmp_header _recent_header">
#              <strong class="tit">
#               최근 검색어
#              </strong>
#              <div class="option">
#               <a aria-pressed="false" class="item _delAll" href="#" role="button">
#                전체삭제
#               </a>
#              </div>
#             </div>
#             <div class="atcmp_container">
#              <ul class="kwd_lst _recent">
#              </ul>
#              <div class="kwd_info kwd_off _offMsg" style="display:none">
#               검색어 저장 기능이 꺼져 있습니다.
#               <br/>
#               <span class="kwd_dsc">
#                설정이 초기화 된다면
#                <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">
#                 도움말
#                </a>
#                을 확인해주세요.
#               </span>
#              </div>
#              <div class="kwd_info kwd_none _recentNone" style="display:none">
#               최근 검색어 내역이 없습니다.
#               <br/>
#               <span class="kwd_dsc">
#                설정이 초기화 된다면
#                <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">
#                 도움말
#                </a>
#                을 확인해주세요.
#               </span>
#              </div>
#             </div>
#             <div class="atcmp_footer">
#              <span class="side_opt_area">
#               <span class="opt_item">
#                <a class="close _keywordOnOff" href="#">
#                 자동저장 끄기
#                </a>
#               </span>
#               <span class="opt_item">
#                <a data-clk="sly.help" href="https://help.naver.com/alias/search/word/word_35.naver" target="_blank">
#                 도움말
#                </a>
#               </span>
#              </span>
#              <span class="rside_opt_area">
#               <span class="opt_item">
#                <a class="close _close" href="#">
#                 닫기
#                </a>
#               </span>
#              </span>
#             </div>
#            </div>
#            <div class="atcmp_fixer _atcmp_layer" style="display:none">
#             <div class="atcmp_container _words">
#              <ul class="kwd_lst _kwd_list">
#              </ul>
#              <div class="atcmp_cue type_line _cue_root">
#               <div class="cue_header">
#                <i class="imgsvg ico_cue">
#                 CUE
#                </i>
#                대화하듯 질문해 보세요
#                <a aria-pressed="false" class="btn_help _tg_btn" href="#" role="button">
#                 <i class="imgsvg ico_alert">
#                  이 정보가 표시된 이유
#                 </i>
#                </a>
#                <div class="layer_plus">
#                 <p class="dsc">
#                  검색어와 포함된 키워드를 기반으로 AI 기술을 활용하여 연관된 추천 질문을 제공합니다.
#                 </p>
#                 <a class="btn_close _tg_btn" href="#" role="button">
#                  <i class="imgsvg ico_close">
#                   레이어 닫기
#                  </i>
#                 </a>
#                </div>
#               </div>
#               <ul class="cue_list _ul">
#               </ul>
#              </div>
#              <div class="atcmp_alert _alert">
#               <div class="dsc_election">
#                <p class="dsc">
#                 <i class="imgsvg ico_election">
#                 </i>
#                 <span class="_alert_passage">
#                 </span>
#                </p>
#                <span class="dsc_inner">
#                 <span class="_alert_passage2">
#                 </span>
#                 <a class="link _alert_link" href="#" target="_blank">
#                  자세히보기
#                 </a>
#                </span>
#               </div>
#              </div>
#              <div class="atcmp_plus _plus">
#               <div class="dsc_plus">
#                <a class="link_dsc" data-clk="sug.cxhelp" href="https://help.naver.com/alias/search/word/word_16.naver" target="_blank">
#                 관심사를 반영한 컨텍스트 자동완성
#                 <i class="imgsvg ico_help">
#                  도움말
#                 </i>
#                </a>
#               </div>
#               <div class="switch">
#                <a aria-pressed="false" class="bt_switch active _plus_btn" href="#" role="button">
#                 <i class="imgsvg ico_option">
#                  컨텍스트 자동완성
#                 </i>
#                </a>
#               </div>
#               <div class="layer_plus _plus_layer">
#                <strong class="tit">
#                 컨텍스트 자동완성
#                </strong>
#                <div class="_plus_layer_isloggedin" style="display:none">
#                 <p class="dsc">
#                  ON/OFF 설정은 해당기기(브라우저)에 저장됩니다.
#                 </p>
#                 <div class="btn_area">
#                  <a class="link_view" data-clk="sug.cxlink" href="https://help.naver.com/alias/search/word/word_16.naver" target="_blank">
#                   자세히 보기
#                  </a>
#                 </div>
#                </div>
#                <div class="_plus_layer_isnotloggedin" style="display:none">
#                 <p class="dsc">
#                  동일한 시간대・연령대・남녀별 사용자 그룹의 관심사에 맞춰 자동완성을 제공합니다.
#                  <a class="link_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                   자세히 보기
#                  </a>
#                 </p>
#                 <div class="btn_area">
#                  <a class="btn btn_login" data-clk="sug.cxlogin" href="https://nid.naver.com/nidlogin.login">
#                   <i class="imgsvg ico_naver">
#                    네이버
#                   </i>
#                   로그인
#                  </a>
#                 </div>
#                </div>
#                <a class="btn_close _plus_layer_close" href="#" role="button">
#                 <i class="imgsvg ico_close">
#                  컨텍스트 자동완성 레이어 닫기
#                 </i>
#                </a>
#               </div>
#              </div>
#             </div>
#             <div class="atcmp_footer">
#              <span class="side_opt_area">
#               <span class="opt_item">
#                <a class="close _suggestOnOff" href="#">
#                 자동완성 끄기
#                </a>
#               </span>
#               <span class="opt_item">
#                <a data-clk="sug.help" href="https://help.naver.com/alias/search/word/word_17.naver" target="_blank">
#                 도움말
#                </a>
#               </span>
#               <span class="opt_item">
#                <a class="report" data-clk="sug.report" href="https://help.naver.com/alias/search/word/word_18.naver" target="_blank">
#                 신고
#                </a>
#               </span>
#              </span>
#              <span class="rside_opt_area">
#               <span class="opt_item">
#                <a class="close _close" href="#">
#                 닫기
#                </a>
#               </span>
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="search-right-banner">
#      </div>
#      <div class="shortcut_area" id="shortcutArea" role="region">
#      </div>
#      <div class="menu_area" id="topAsideArea">
#      </div>
#      <div class="pay_area" id="topPayArea">
#      </div>
#      <div class="talk_area" id="topTalkArea">
#      </div>
#      <div class="notify_area" id="topNotiArea">
#      </div>
#     </div>
#    </div>
#    <div id="container" role="main">
#     <div id="root">
#     </div>
#    </div>
#    <div id="footer" role="contentinfo">
#    </div>
#   </div>
#   <script>
#    window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20240118162502',  };
#   </script>
#   <script>
#    !function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(()=>{var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var s=i&&i.content&&i.content.input&&i.content.input.placeholder;if(s){var o=document.getElementById("query");o&&s&&o.setAttribute("title",s),o&&s&&o.setAttribute("placeholder",s)}}()
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## 속성 데이터

# %%
html = """<html> <head><title class="t" id="ti">test site</title></head> <body> <p>test</p> <p>test1</p> <p>test2</p> </body></html>"""

# %% [markdown]
# - html
#     - head
#         - title
#             - 속성
#                 - class : t
#                 - id : ti
#     - body
#         - p
#         - p
#         - p

# %%
soup = BeautifulSoup(html, "lxml")

# %%
print(soup)
# Out:
# <html> <head><title class="t" id="ti">test site</title></head> <body> <p>test</p> <p>test1</p> <p>test2</p> </body></html>

# %%
tag_title = soup.title # soup 안에서 title 태그 찾기

# %%
print(tag_title)
print(tag_title.attrs) # 태그의 속성 가져오기
print(tag_title["class"]) # 키가 없으면 에러 발생
print(tag_title["id"])
# Out:
# <title class="t" id="ti">test site</title>
# {'class': ['t'], 'id': 'ti'}
# ['t']
# ti

# %%
tag_title["class1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tag_title["class1"]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bs4\element.py:1573, in Tag.__getitem__(self, key)
#    1570 def __getitem__(self, key):
#    1571     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1572     and throws an exception if it's not there."""
# -> 1573     return self.attrs[key]
#
# KeyError: 'class1'

# %%
# tag 타입은 딕셔너러리처럼 접근할 수 있고 딕셔너리 문법을 그대로 적용할 수 있음
tag_title.get("class1", "default_value") # class1이 없으면 dafault_value의 값을 가져 와라
# Out:
# 'default_value'

# %%
type(tag_title)
# Out:
# bs4.element.Tag

# %% [markdown]
# ### 태그 접근

# %%
tag_title = soup.title # title 태그
print(tag_title)
# Out:
# <title class="t" id="ti">test site</title>

# %% [markdown]
# - soup.태그이름 의 형태로 첫 번째로 등장하는 태그의 정보를 가져올 수 있음

# %%
print(tag_title.text)
print(tag_title.string)
print(tag_title.name)
# Out:
# test site
# test site
# title

# %%
# text와 string의 차이
html = """<html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>"""

# %% [markdown]
# - html
#     - head
#         - title
#     - body
#         - p
#             - span
#             - span

# %% [markdown]
# - test1, test2는 p 태그가 갖고 있는게 아니라 p의 자식인 span이 갖고 있음

# %%
soup = BeautifulSoup(html, "lxml")

tag_p = soup.p

data_text = tag_p.text
data_string = tag_p.string

print(data_text, type(data_text))
print(data_string, type(data_string))
# Out:
# test1test2 <class 'str'>
# None <class 'NoneType'>

# %% [markdown]
# - text : 하위 태그들의 값도 모두 출력
# - string : 정확히 해당 태그에 대한 값만 출력

# %%
# string으로 test1을 출력하려면
tag_p # <p><span>test1</span><span>test2</span></p>
tag_p.span # <span>test1</span>
tag_p.span.string # 'test1'
# Out:
# 'test1'

# %% [markdown]
# ### 자식 태그 접근
#
# - content와 children 속성을 이용하여 자식 태그 가져오기

# %%
soup
# Out:
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>

# %%
soup.p
# Out:
# <p><span>test1</span><span>test2</span></p>

# %%
tag_p_children = soup.p.contents # 리스트 형태로 자식 태그들을 가져옴
print(tag_p_children)
# Out:
# [<span>test1</span>, <span>test2</span>]

# %%
tag_p_children = soup.p.children # children으로 가져온 값은 반복문을 사용해야함

for child in tag_p_children:
    print(child)
# Out:
# <span>test1</span>
# <span>test2</span>

# %% [markdown]
# ### 부모 태그 접근
#
# - parent 와 parents 로 부모 태그 가져오기

# %%
soup
# Out:
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>

# %%
soup.span
# Out:
# <span>test1</span>

# %%
soup.title
# Out:
# <title>test site</title>

# %%
tag_span = soup.span
tag_title = soup.title

span_parent = tag_span.parent
title_parent = tag_title.parent

print(span_parent)
print(title_parent)
# Out:
# <p><span>test1</span><span>test2</span></p>
# <head><title>test site</title></head>

# %%
span_parents = tag_span.parents
title_parents = tag_title.parents

for parent in span_parents:
    print(parent) # p > body > html > 전체
    
print()

for parent in title_parents:
    print(parent) # head > html > 전체
# Out:
# <p><span>test1</span><span>test2</span></p>
# <body> <p><span>test1</span><span>test2</span></p> </body>
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>
#
# <head><title>test site</title></head>
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>
# <html> <head><title>test site</title></head> <body> <p><span>test1</span><span>test2</span></p> </body></html>

# %% [markdown]
# ### 형제 태그 접근
#
# - 형제 태그 : 동등한 위치의 태그

# %%
tag_span
# Out:
# <span>test1</span>

# %%
a = tag_span.next_sibling
print(a)
# Out:
# <span>test2</span>

# %%
b = a.previous_sibling 
print(b)
# Out:
# <span>test1</span>

# %%
print(a.next_sibling)
print(b.previous_sibling)
# Out:
# None
# None

# %% [markdown]
#  ### 다음 요소, 이전 요소 접근하기
#
#  - next_element, previous_element
#  - 형제 태그와의 차이
#      - 형제 태그 : 동일한 위치의 태그들만
#      - 요소 : 태그도 포함하지만 그 안의 자식태그와 문자도 포함하는 개념

# %%
html = """<html> <head><title>test site</title></head> <body> <p><a>test1</a><b>test2</b><c>test3</c></p> </body></html>"""

# %% [markdown]
# - html
#     - head
#         - title
#     - body
#         - p
#             - a
#             - b
#             - c

# %%
soup = BeautifulSoup(html, "lxml")

tag_a = soup.a
print(tag_a)
# Out:
# <a>test1</a>

# %%
tag_a_nexts = tag_a.next_elements # a 태그의 다음 요소들

for i in tag_a_nexts:
    print(i)
# Out:
# test1
# <b>test2</b>
# test2
# <c>test3</c>
# test3

# %% [markdown]
# ## 원하는 요소에 접근하기

# %% [markdown]
# ### find_all()
#
# - 원하는 태그들을 리스트 형태로 가져오기

# %%
html = """<html> <head><title>test site</title></head> <body> <p id="i" class="a">test1</p><p id="d" class="d">test2</p><p class="c">test3</p></p><a>a tag</a> <b>b tag</b></body></html>"""

# %% [markdown]
# - html
#     - head
#         - title
#     - body
#         - p(id = i, class = a)
#         - p(id = d, class = d)
#         - p(class = c)
#         - a
#         - b

# %%
soup = BeautifulSoup(html, "lxml")

# %%
soup.find_all("title") # 해당 태그를 전부 찾아서 [리스트] 형태로 가져옴
# Out:
# [<title>test site</title>]

# %%
soup.find_all("p")
# Out:
# [<p class="a" id="i">test1</p>,
#  <p class="d" id="d">test2</p>,
#  <p class="c">test3</p>]

# %% [markdown]
# - id값으로 태그 가져오기

# %%
soup.find_all(id = "d")
# Out:
# [<p class="d" id="d">test2</p>]

# %%
# id의 존재 여부로 데이터 가져오기
print(soup.find_all(id = True))
# Out:
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>]

# %%
print(soup.body.find_all(id = False))
# Out:
# [<p class="c">test3</p>, <a>a tag</a>, <b>b tag</b>]

# %%
print(soup.find_all(id = False)) 
# body 태그를 넣지 않으면 모두 출력되기 때문에 body를 넣어야 함!
# Out:
# [<html> <head><title>test site</title></head> <body> <p class="a" id="i">test1</p><p class="d" id="d">test2</p><p class="c">test3</p><a>a tag</a> <b>b tag</b></body></html>, <head><title>test site</title></head>, <title>test site</title>, <body> <p class="a" id="i">test1</p><p class="d" id="d">test2</p><p class="c">test3</p><a>a tag</a> <b>b tag</b></body>, <p class="c">test3</p>, <a>a tag</a>, <b>b tag</b>]

# %% [markdown]
# - 원하는 태그, 원하는 id 값으로 태그 가져오기

# %%
print(soup.find_all("p", id = "d"))
print(soup.find_all("p", id = "c")) # 없으면 빈 리스트 반환
# Out:
# [<p class="d" id="d">test2</p>]
# []

# %% [markdown]
# - text 속성으로 태그 가져오기 (다음 버전에서 삭제 예정)

# %%
print(soup.find_all("p", text = "test1")) # p 태그 중에서 test1 이라는 값을 가진 태그
print(soup.find_all("p", text = "t"))
# Out:
# [<p class="a" id="i">test1</p>]
# []
# C:\Users\ITSC\AppData\Local\Temp\ipykernel_2140\1756851297.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   print(soup.find_all("p", text = "test1")) # p 태그 중에서 test1 이라는 값을 가진 태그
# C:\Users\ITSC\AppData\Local\Temp\ipykernel_2140\1756851297.py:2: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   print(soup.find_all("p", text = "t"))

# %% [markdown]
# - limit 로 가져오는 태그 수 제한

# %%
print(soup.find_all("p"))
# Out:
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>, <p class="c">test3</p>]

# %%
print(soup.find_all("p", limit = 1))
print(soup.find_all("p", limit = 2))
print(soup.find_all("p", limit = 5)) # 태그의 양보다 많아도 에러를 띄우지 않음
# Out:
# [<p class="a" id="i">test1</p>]
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>]
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>, <p class="c">test3</p>]

# %%
# find_all에 아무런 값도 넣지 않으면 모든 태그를 가져옴
soup.find_all()
# Out:
# [<html> <head><title>test site</title></head> <body> <p class="a" id="i">test1</p><p class="d" id="d">test2</p><p class="c">test3</p><a>a tag</a> <b>b tag</b></body></html>,
#  <head><title>test site</title></head>,
#  <title>test site</title>,
#  <body> <p class="a" id="i">test1</p><p class="d" id="d">test2</p><p class="c">test3</p><a>a tag</a> <b>b tag</b></body>,
#  <p class="a" id="i">test1</p>,
#  <p class="d" id="d">test2</p>,
#  <p class="c">test3</p>,
#  <a>a tag</a>,
#  <b>b tag</b>]

# %% [markdown]
# - 여러 태그 동시에 가져오기

# %%
soup.find_all(["a", "b"])
# Out:
# [<a>a tag</a>, <b>b tag</b>]

# %% [markdown]
# - find_all() 연속으로 사용하기

# %%
tag_body = soup.find_all("body")
print(tag_body)
tag_body[0].find_all("p")
# Out:
# [<body> <p class="a" id="i">test1</p><p class="d" id="d">test2</p><p class="c">test3</p><a>a tag</a> <b>b tag</b></body>]
# [<p class="a" id="i">test1</p>,
#  <p class="d" id="d">test2</p>,
#  <p class="c">test3</p>]

# %% [markdown]
# ### find()
#
# - 하나의 요소만 가져옴
# - 찾고자 하는 요소가 하나만 있을 때 사용
#     - 예) id 값으로 접근

# %%
soup.find("p")
# Out:
# <p class="a" id="i">test1</p>

# %%
print(soup.find("p", class_ = "d"))
print(soup.find("p", id = "i"))
# Out:
# <p class="d" id="d">test2</p>
# <p class="a" id="i">test1</p>

# %%
# 연속으로 find() 사용
soup.find("body").find("p", class_ = "d")
# Out:
# <p class="d" id="d">test2</p>

# %% [markdown]
# ### select()
#
# - find_all()과 마찬가지로 매칭되는 결과를 리스트로 반환
# - 클래스는 마침표(.), 아이디는 샵(#)으로 자손태그는 띄어쓰기로 표현 자식태그는 (>)로 표현
# - select_one()으로 하나의 결과만 반환하는 것도 가능

# %%
print(soup.select("p")) # p태그들
print(soup.select(".d")) # 클래스가 d인 태그들
print(soup.select("p.d")) # 클래스가 d인 p태그들
print(soup.select("#i")) # id가 i인 태그들
print(soup.select("p#i")) # id가 i인 p태그들
# Out:
# [<p class="a" id="i">test1</p>, <p class="d" id="d">test2</p>, <p class="c">test3</p>]
# [<p class="d" id="d">test2</p>]
# [<p class="d" id="d">test2</p>]
# [<p class="a" id="i">test1</p>]
# [<p class="a" id="i">test1</p>]

# %%
html = """<html> <head><title>test site</title></head> <body> <div><p id="i" class="a">test1</p><p class="d">test2</p></div><p class="d">test3</p></p> <a>a tag</a> <b>b tag</b></body></html>"""

# %% [markdown]
# - html
#     - head
#         - tittle
#     - body
#         - div
#             - p(id = i, class = a)
#             - p(class = d)
#         - p(class = d)
#         - a
#         - b

# %%
soup = BeautifulSoup(html, "lxml")

# %%
print(soup.select("body p")) # body의 자손인 p태그들
# Out:
# [<p class="a" id="i">test1</p>, <p class="d">test2</p>, <p class="d">test3</p>]

# %%
print(soup.select("body .d")) # body 자손이면서 클래스가 d인 태그들
# Out:
# [<p class="d">test2</p>, <p class="d">test3</p>]

# %%
print(soup.select("body p.d")) # body의 자손이면서 클래스가 d인 p태그들
# Out:
# [<p class="d">test2</p>, <p class="d">test3</p>]

# %%
print(soup.select("body #i")) # body의 자손이면서 id가 i인 태그들
# Out:
# [<p class="a" id="i">test1</p>]

# %%
print(soup.select("body p#i")) # body의 자손이면서 id가 i인 p태그들
# Out:
# [<p class="a" id="i">test1</p>]

# %%
print(soup.select("div p")) # div의 자손인 p태그들
# Out:
# [<p class="a" id="i">test1</p>, <p class="d">test2</p>]

# %% [markdown]
# ## 웹크롤링 허용 문제
#
# - 모든 사이트에는 웹 크롤링 권한에 관해 명시한 페이지가 있음
#     - 사이트 url끝에 robots.txt를 붙여서 확인
#         - 예) http://www.google.com/robots.txt
#         - Disallow : 허용되지 않는 경로
#         - Allow : 크롤링을 허용하는 경로

# %% [markdown]
# ### 예제 1-1. 티스토리 크롤링

# %%
url = "https://ai-dev.tistory.com/1"

page = urlopen(url)

soup = BeautifulSoup(page, "lxml")

# %%
# 제목 수집
soup.select_one("div.hgroup > h1").string.strip()
# Out:
# '크롤링의 세계에 오신 것을 환영합니다.'

# %%
# 게시물 내용 수집
# Hello, world!

soup.select_one("div.tt_article_useless_p_margin.contents_style > p").string
# Out:
# 'Hello, world!'

# %%
url = "https://ai-dev.tistory.com/2"

page = urlopen(url)

soup = BeautifulSoup(page, "lxml")

# %%
soup.select("div.tt_article_useless_p_margin.contents_style tbody tr td")
# Out:
# [<td style="width: 33.3333%; text-align: center;">상품</td>,
#  <td style="width: 33.3333%; text-align: center;">색상</td>,
#  <td style="width: 33.3333%; text-align: center;">가격</td>,
#  <td style="width: 33.3333%; text-align: center;">셔츠1</td>,
#  <td style="width: 33.3333%; text-align: center;">빨강</td>,
#  <td style="width: 33.3333%; text-align: center;">20000</td>,
#  <td style="width: 33.3333%; text-align: center;">셔츠2</td>,
#  <td style="width: 33.3333%; text-align: center;">파랑</td>,
#  <td style="width: 33.3333%; text-align: center;">19000</td>,
#  <td style="width: 33.3333%; text-align: center;">셔츠3</td>,
#  <td style="width: 33.3333%; text-align: center;">초록</td>,
#  <td style="width: 33.3333%; text-align: center;">18000</td>,
#  <td style="width: 33.3333%; text-align: center;">바지1</td>,
#  <td style="width: 33.3333%; text-align: center;">검정</td>,
#  <td style="width: 33.3333%; text-align: center;">50000</td>,
#  <td style="width: 33.3333%; text-align: center;">바지2</td>,
#  <td style="width: 33.3333%; text-align: center;">파랑</td>,
#  <td style="width: 33.3333%; text-align: center;">51000</td>]

# %%
# 테이블 내용 수집
table_text = soup.select("div.tt_article_useless_p_margin td")
print(table_text)
# Out:
# [<td style="width: 33.3333%; text-align: center;">상품</td>, <td style="width: 33.3333%; text-align: center;">색상</td>, <td style="width: 33.3333%; text-align: center;">가격</td>, <td style="width: 33.3333%; text-align: center;">셔츠1</td>, <td style="width: 33.3333%; text-align: center;">빨강</td>, <td style="width: 33.3333%; text-align: center;">20000</td>, <td style="width: 33.3333%; text-align: center;">셔츠2</td>, <td style="width: 33.3333%; text-align: center;">파랑</td>, <td style="width: 33.3333%; text-align: center;">19000</td>, <td style="width: 33.3333%; text-align: center;">셔츠3</td>, <td style="width: 33.3333%; text-align: center;">초록</td>, <td style="width: 33.3333%; text-align: center;">18000</td>, <td style="width: 33.3333%; text-align: center;">바지1</td>, <td style="width: 33.3333%; text-align: center;">검정</td>, <td style="width: 33.3333%; text-align: center;">50000</td>, <td style="width: 33.3333%; text-align: center;">바지2</td>, <td style="width: 33.3333%; text-align: center;">파랑</td>, <td style="width: 33.3333%; text-align: center;">51000</td>]

# %%
for i in table_text:
    print(i.string)
# Out:
# 상품
# 색상
# 가격
# 셔츠1
# 빨강
# 20000
# 셔츠2
# 파랑
# 19000
# 셔츠3
# 초록
# 18000
# 바지1
# 검정
# 50000
# 바지2
# 파랑
# 51000

# %%
[i.string for i in table_text]
# Out:
# ['상품',
#  '색상',
#  '가격',
#  '셔츠1',
#  '빨강',
#  '20000',
#  '셔츠2',
#  '파랑',
#  '19000',
#  '셔츠3',
#  '초록',
#  '18000',
#  '바지1',
#  '검정',
#  '50000',
#  '바지2',
#  '파랑',
#  '51000']

# %%
text_zip = soup.select("div.tt_article_useless_p_margin li")

# %%
for i in text_zip:
    print(i.string)
# Out:
# 모니터
# CPU
# 메모리
# 그래픽카드
# 하드디스크
# 키보드
# 마우스

# %%
url = "https://music.bugs.co.kr/chart"

page = urlopen(url)

soup = BeautifulSoup(page, "lxml")

# %%
title = soup.select("div#CHARTrealtime th p a")
print(title)
# Out:
# [<a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6228128',true);
# " title="Love 119">Love 119</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6223772',true);
# " title="To. X">To. X</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33037501',true);
# " title="비의 랩소디">비의 랩소디</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6220482',true);
# " title="Perfect Night">Perfect Night</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6221970',true);
# " title="Drama">Drama</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6221133',true);
# " title="MANIAC">MANIAC</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6225822',true);
# " title="에피소드">에피소드</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6213292',true);
# " title="Get A Guitar">Get A Guitar</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6228208',true);
# " title="DASH">DASH</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6195812',true);
# " title="I AM">I AM</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6212711',true);
# " title="그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))">그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6217653',true);
# " title="You &amp; Me">You &amp; Me</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('32422516',true);
# " title="인사">인사</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6196923',true);
# " title="헤어지자 말해요">헤어지자 말해요</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6184997',true);
# " title="Ditto">Ditto</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('31650949',true);
# " title="한 페이지가 될 수 있게">한 페이지가 될 수 있게</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6218218',true);
# " title="Baddie">Baddie</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6229790',true);
# " title="Yes or No (Feat. 허윤진 of LE SSERAFIM, Crush)">Yes or No (Feat. 허윤진 of LE SSERAFIM, Crush)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6208880',true);
# " title="ETA">ETA</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6218697',true);
# " title="Discord">Discord</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6170217',true);
# " title="Hype Boy">Hype Boy</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6213264',true);
# " title="Love Lee">Love Lee</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('3306856',true);
# " title="첫 눈">첫 눈</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6213265',true);
# " title="후라이의 꿈">후라이의 꿈</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6220473',true);
# " title="Talk Saxy">Talk Saxy</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6207490',true);
# " title="Seven (feat. Latto) - Clean Ver.">Seven (feat. Latto) - Clean Ver.</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6226090',true);
# " title="넌 쉽게 말했지만">넌 쉽게 말했지만</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6206291',true);
# " title="Super Shy">Super Shy</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('103259794',true);
# " title="Steal The Show (From “엘리멘탈”)">Steal The Show (From “엘리멘탈”)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6219579',true);
# " title="잠시라도 우리">잠시라도 우리</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6221238',true);
# " title="Standing Next to You">Standing Next to You</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('32976487',true);
# " title="GODS">GODS</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6222137',true);
# " title="Chill Kill">Chill Kill</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30540153',true);
# " title="예뻤어">예뻤어</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6173357',true);
# " title="숲">숲</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6226908',true);
# " title="화이트 (White)">화이트 (White)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('32845387',true);
# " title="Spicy">Spicy</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6217625',true);
# " title="Off The Record">Off The Record</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('3387407',true);
# " title="너의 모든 순간">너의 모든 순간</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6155092',true);
# " title="사건의 지평선">사건의 지평선</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('5502261',true);
# " title="그대가 내 안에 박혔다">그대가 내 안에 박혔다</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6194446',true);
# " title="Kitsch">Kitsch</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6215110',true);
# " title="별 떨어진다 (I Do)">별 떨어진다 (I Do)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6229554',true);
# " title="기억해줘요 내 모든 날과 그때를">기억해줘요 내 모든 날과 그때를</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6229269',true);
# " title="머물러주오 (Prod. 안신애 &amp; Philtre)">머물러주오 (Prod. 안신애 &amp; Philtre)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6170060',true);
# " title="Attention">Attention</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6173112',true);
# " title="After LIKE">After LIKE</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6155955',true);
# " title="LOVE DIVE">LOVE DIVE</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6230125',true);
# " title="한번만 더">한번만 더</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6216911',true);
# " title="Either Way">Either Way</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6225562',true);
# " title="사랑할 수밖에">사랑할 수밖에</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('31708907',true);
# " title="어떻게 이별까지 사랑하겠어, 널 사랑하는 거지">어떻게 이별까지 사랑하겠어, 널 사랑하는 거지</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6219917',true);
# " title="음악의 신">음악의 신</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6199292',true);
# " title="퀸카 (Queencard)">퀸카 (Queencard)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6186207',true);
# " title="OMG">OMG</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6197839',true);
# " title="이브, 프시케 그리고 푸른 수염의 아내">이브, 프시케 그리고 푸른 수염의 아내</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6226230',true);
# " title="꿈">꿈</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6228191',true);
# " title="Try Again">Try Again</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6206268',true);
# " title="New Jeans">New Jeans</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6205698',true);
# " title="잘 지내자, 우리 (여름날 우리 X 로이킴)">잘 지내자, 우리 (여름날 우리 X 로이킴)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6211874',true);
# " title="Fast Forward">Fast Forward</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('4669063',true);
# " title="Dangerously">Dangerously</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6176123',true);
# " title="I Don’t Think That I Like Her">I Don’t Think That I Like Her</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6188211',true);
# " title="그대가 내 안에 박혔다(그내박)">그대가 내 안에 박혔다(그내박)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6178672',true);
# " title="Underwater">Underwater</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6189316',true);
# " title="파이팅 해야지 (Feat. 이영지)">파이팅 해야지 (Feat. 이영지)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6229268',true);
# " title="I Love You (Prod. 김도훈)">I Love You (Prod. 김도훈)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('30994623',true);
# " title="모든 날, 모든 순간 (Every day, Every Moment)">모든 날, 모든 순간 (Every day, Every Moment)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6214823',true);
# " title="Smoke (Prod. Dynamicduo, Padi)">Smoke (Prod. Dynamicduo, Padi)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('31501137',true);
# " title="주저하는 연인들을 위해">주저하는 연인들을 위해</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6228245',true);
# " title="I Love You">I Love You</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33026843',true);
# " title="DIE 4 YOU">DIE 4 YOU</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6197215',true);
# " title="손오공">손오공</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('98493924',true);
# " title="건물 사이에 피어난 장미 (Rose Blossom)">건물 사이에 피어난 장미 (Rose Blossom)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6147666',true);
# " title="사랑인가 봐">사랑인가 봐</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6213192',true);
# " title="달빛에 그려지는">달빛에 그려지는</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6110464',true);
# " title="다정히 내 이름을 부르면">다정히 내 이름을 부르면</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6197837',true);
# " title="UNFORGIVEN (feat. Nile Rodgers)">UNFORGIVEN (feat. Nile Rodgers)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6190714',true);
# " title="심(心)">심(心)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('32907442',true);
# " title="사막에서 꽃을 피우듯">사막에서 꽃을 피우듯</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('81510510',true);
# " title="STAY">STAY</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6212752',true);
# " title="Bubble">Bubble</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33022918',true);
# " title="미워 (Ego)">미워 (Ego)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('95808160',true);
# " title="When I Get Old">When I Get Old</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('32566640',true);
# " title="Summer (Feat. BE’O (비오))">Summer (Feat. BE’O (비오))</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6131070',true);
# " title="사랑은 늘 도망가">사랑은 늘 도망가</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('31703429',true);
# " title="운이 좋았지">운이 좋았지</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6229483',true);
# " title="@은영이에게">@은영이에게</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6223773',true);
# " title="Melt Away">Melt Away</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6179181',true);
# " title="ANTIFRAGILE">ANTIFRAGILE</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6208707',true);
# " title="Cool With You">Cool With You</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33041141',true);
# " title="입술 (Feat. 10CM)">입술 (Feat. 10CM)</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('31009023',true);
# " title="어른">어른</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('76991868',true);
# " title="Off My Face">Off My Face</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33075374',true);
# " title="내일 얘기해">내일 얘기해</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6140459',true);
# " title="취중고백">취중고백</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6224281',true);
# " title="그대가 있는 곳, 언제 어디든">그대가 있는 곳, 언제 어디든</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6220480',true);
# " title="밤, 바다">밤, 바다</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('5035960',true);
# " title="Snowman">Snowman</a>, <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('33041525',true);
# " title="Soñar (Breaker)">Soñar (Breaker)</a>]

# %%
for i in title:
    print(i.string)
# Out:
# Love 119
# To. X
# 비의 랩소디
# Perfect Night
# Drama
# MANIAC
# 에피소드
# Get A Guitar
# DASH
# I AM
# 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
# You & Me
# 인사
# 헤어지자 말해요
# Ditto
# 한 페이지가 될 수 있게
# Baddie
# Yes or No (Feat. 허윤진 of LE SSERAFIM, Crush)
# ETA
# Discord
# Hype Boy
# Love Lee
# 첫 눈
# 후라이의 꿈
# Talk Saxy
# Seven (feat. Latto) - Clean Ver.
# 넌 쉽게 말했지만
# Super Shy
# Steal The Show (From “엘리멘탈”)
# 잠시라도 우리
# Standing Next to You
# GODS
# Chill Kill
# 예뻤어
# 숲
# 화이트 (White)
# Spicy
# Off The Record
# 너의 모든 순간
# 사건의 지평선
# 그대가 내 안에 박혔다
# Kitsch
# 별 떨어진다 (I Do)
# 기억해줘요 내 모든 날과 그때를
# 머물러주오 (Prod. 안신애 & Philtre)
# Attention
# After LIKE
# LOVE DIVE
# 한번만 더
# Either Way
# 사랑할 수밖에
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 음악의 신
# 퀸카 (Queencard)
# OMG
# 이브, 프시케 그리고 푸른 수염의 아내
# 꿈
# Try Again
# New Jeans
# 잘 지내자, 우리 (여름날 우리 X 로이킴)
# Fast Forward
# Dangerously
# I Don’t Think That I Like Her
# 그대가 내 안에 박혔다(그내박)
# Underwater
# 파이팅 해야지 (Feat. 이영지)
# I Love You (Prod. 김도훈)
# 모든 날, 모든 순간 (Every day, Every Moment)
# Smoke (Prod. Dynamicduo, Padi)
# 주저하는 연인들을 위해
# I Love You
# DIE 4 YOU
# 손오공
# 건물 사이에 피어난 장미 (Rose Blossom)
# 사랑인가 봐
# 달빛에 그려지는
# 다정히 내 이름을 부르면
# UNFORGIVEN (feat. Nile Rodgers)
# 심(心)
# 사막에서 꽃을 피우듯
# STAY
# Bubble
# 미워 (Ego)
# When I Get Old
# Summer (Feat. BE’O (비오))
# 사랑은 늘 도망가
# 운이 좋았지
# @은영이에게
# Melt Away
# ANTIFRAGILE
# Cool With You
# 입술 (Feat. 10CM)
# 어른
# Off My Face
# 내일 얘기해
# 취중고백
# 그대가 있는 곳, 언제 어디든
# 밤, 바다
# Snowman
# Soñar (Breaker)

# %%
title2 = soup.select("p.title > a")

# %%
for i in title2:
    print(i.string)
# Out:
# Love 119
# To. X
# 비의 랩소디
# Perfect Night
# Drama
# MANIAC
# 에피소드
# Get A Guitar
# DASH
# I AM
# 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
# You & Me
# 인사
# 헤어지자 말해요
# Ditto
# 한 페이지가 될 수 있게
# Baddie
# Yes or No (Feat. 허윤진 of LE SSERAFIM, Crush)
# ETA
# Discord
# Hype Boy
# Love Lee
# 첫 눈
# 후라이의 꿈
# Talk Saxy
# Seven (feat. Latto) - Clean Ver.
# 넌 쉽게 말했지만
# Super Shy
# Steal The Show (From “엘리멘탈”)
# 잠시라도 우리
# Standing Next to You
# GODS
# Chill Kill
# 예뻤어
# 숲
# 화이트 (White)
# Spicy
# Off The Record
# 너의 모든 순간
# 사건의 지평선
# 그대가 내 안에 박혔다
# Kitsch
# 별 떨어진다 (I Do)
# 기억해줘요 내 모든 날과 그때를
# 머물러주오 (Prod. 안신애 & Philtre)
# Attention
# After LIKE
# LOVE DIVE
# 한번만 더
# Either Way
# 사랑할 수밖에
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 음악의 신
# 퀸카 (Queencard)
# OMG
# 이브, 프시케 그리고 푸른 수염의 아내
# 꿈
# Try Again
# New Jeans
# 잘 지내자, 우리 (여름날 우리 X 로이킴)
# Fast Forward
# Dangerously
# I Don’t Think That I Like Her
# 그대가 내 안에 박혔다(그내박)
# Underwater
# 파이팅 해야지 (Feat. 이영지)
# I Love You (Prod. 김도훈)
# 모든 날, 모든 순간 (Every day, Every Moment)
# Smoke (Prod. Dynamicduo, Padi)
# 주저하는 연인들을 위해
# I Love You
# DIE 4 YOU
# 손오공
# 건물 사이에 피어난 장미 (Rose Blossom)
# 사랑인가 봐
# 달빛에 그려지는
# 다정히 내 이름을 부르면
# UNFORGIVEN (feat. Nile Rodgers)
# 심(心)
# 사막에서 꽃을 피우듯
# STAY
# Bubble
# 미워 (Ego)
# When I Get Old
# Summer (Feat. BE’O (비오))
# 사랑은 늘 도망가
# 운이 좋았지
# @은영이에게
# Melt Away
# ANTIFRAGILE
# Cool With You
# 입술 (Feat. 10CM)
# 어른
# Off My Face
# 내일 얘기해
# 취중고백
# 그대가 있는 곳, 언제 어디든
# 밤, 바다
# Snowman
# Soñar (Breaker)
