# %%
# !pip install git+https://github.com/JaidedAI/EasyOCR.git
# Out:
# Collecting git+https://github.com/JaidedAI/EasyOCR.git
#   Cloning https://github.com/JaidedAI/EasyOCR.git to c:\users\itsc\appdata\local\temp\pip-req-build-buray6jh
#   Resolved https://github.com/JaidedAI/EasyOCR.git to commit c999505ef6b43be1c4ee36aa04ad979175178352
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: torch in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (2.2.2)
# Requirement already satisfied: torchvision>=0.5 in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (0.17.2)
# Requirement already satisfied: opencv-python-headless in c:\users\itsc\appdata\roaming\python\python311\site-packages (from easyocr==1.7.1) (4.9.0.80)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (1.11.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (1.24.3)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (9.4.0)
# Requirement already satisfied: scikit-image in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (0.20.0)
# Requirement already satisfied: python-bidi in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (0.4.2)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (6.0)
# Requirement already satisfied: Shapely in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (2.0.4)
# Requirement already satisfied: pyclipper in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\programdata\anaconda3\lib\site-packages (from easyocr==1.7.1) (1.11.1.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch->easyocr==1.7.1) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\programdata\anaconda3\lib\site-packages (from torch->easyocr==1.7.1) (4.10.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch->easyocr==1.7.1) (1.11.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch->easyocr==1.7.1) (3.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch->easyocr==1.7.1) (3.1.2)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch->easyocr==1.7.1) (2024.3.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from python-bidi->easyocr==1.7.1) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->easyocr==1.7.1) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->easyocr==1.7.1) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->easyocr==1.7.1) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->easyocr==1.7.1) (23.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image->easyocr==1.7.1) (0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch->easyocr==1.7.1) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch->easyocr==1.7.1) (1.3.0)
#   Running command git clone --filter=blob:none --quiet https://github.com/JaidedAI/EasyOCR.git 'C:\Users\ITSC\AppData\Local\Temp\pip-req-build-buray6jh'

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = "True"

# %%
import easyocr
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt
from PIL import ImageFont, ImageDraw, Image

# %%
reader = easyocr.Reader(["ko", "en"])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |█-------------------------------------------------| 2.6% Complete
# Progress: |████----------------------------------------------| 9.2% Complete
# Progress: |████████------------------------------------------| 16.1% Complete
# Progress: |██████████----------------------------------------| 20.2% Complete
# Progress: |█████████████-------------------------------------| 26.8% Complete
# Progress: |████████████████----------------------------------| 33.9% Complete
# Progress: |████████████████████------------------------------| 40.9% Complete
# Progress: |████████████████████████--------------------------| 48.3% Complete
# Progress: |████████████████████████████----------------------| 56.0% Complete
# Progress: |███████████████████████████████-------------------| 63.6% Complete
# Progress: |███████████████████████████████████---------------| 71.0% Complete
# Progress: |███████████████████████████████████████-----------| 78.3% Complete
# Progress: |███████████████████████████████████████████-------| 86.1% Complete
# Progress: |██████████████████████████████████████████████----| 93.4% Complete
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |████----------------------------------------------| 8.6% Complete
# Progress: |██████████████████--------------------------------| 36.5% Complete
# Progress: |████████████████████████████████------------------| 64.1% Complete
# Progress: |██████████████████████████████████████████████████| 100.1% Complete

# %%
result = reader.readtext("./img/dobby.jpg")

# %%
img = cv2.imread("./img/dobby.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img = Image.fromarray(img)
font = ImageFont.truetype("fonts/HMKMRHD.TTF", 20)
draw = ImageDraw.Draw(img)

# %%
COLORS = np.random.randint(0, 255, size = (255, 3), dtype = "uint8")

# %%
for i in result:
    x = i[0][0][0]
    y = i[0][0][1]
    w = i[0][1][0] - i[0][0][0]
    h = i[0][2][1] - i[0][1][1]
    
    color_idx = random.randint(0, 255)
    color = [int(c) for c in COLORS[color_idx]]
    
    draw.rectangle(((x, y), (x + w, y + h)), outline = tuple(color), width = 2)
    draw.text((int((x + x + w) / 2), y - 2), str(i[1]), font = font, fill = tuple(color),)

plt.imshow(img)
plt.show()
